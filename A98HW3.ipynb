# %%
def computePower(x,y):
    z = 1
    for i in range(y):
        z *= x 
    return z

# %%
computePower(3,3)
# Out:
# 27

# %%
readings = []
def temprange(readings):
    range = (min(readings), max(readings))
    return range

# %%
temprange([1,2,3,4])
# Out:
# (1, 4)

# %%
day = 0
def isWeekend(day):
    if day > 5:
        return True

# %%
isWeekend(6)
# Out:
# True

# %%
def fuelefficiency(distance, fuel):
    efficiency = distance/fuel
    return efficiency

# %%
fuelefficiency(100,100)
# Out:
# 1.0

# %%
fuelefficiency(100,50)
# Out:
# 2.0

# %%
def decodenum(n):
    i = n % 10
    j = 0
    while n // (10 ** j) > 0:
        j += 1
        if n // (10 ** j) == 0:
            new_power = j
    cypher = int((n // 10) + (i * (10 ** j))/10)
    return cypher

# %%
decodenum(254)
# Out:
# 425
